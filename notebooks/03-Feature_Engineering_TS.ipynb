# %% [markdown]
# ---
#
# This notebook contains the Feature Engineering for the first module of the **"Intelligent System for Supply Chain Management"** project.
#
# ---

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import os
import json
import plotly.express as px
import plotly.io as pio


# Configure display and graphs
pd.set_option('display.max_columns', None)
pio.templates.default = "plotly_white"

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Load Data

# %%
# Define data paths
data_path = os.path.join('../data', 'processed')
docs_path = os.path.join('../docs/')

# Load Pickle file
read_data = pd.read_parquet(data_path + '/grocery.parquet')

# Load column descriptions from JSON file into a dictionary for reference or documentation
with open(docs_path + 'column_descriptions.json') as f:
    column_descriptions = json.load(f)

# %%
# View dataframe initial shape
read_data.shape
# Out:
# (97646, 33)

# %%
order_columns = read_data.columns.tolist()

# %%
# Select columns for dtype 
number_max = ['delivery_lag', 'lead_time', 'max_stock']
number_mean = list(set(read_data.select_dtypes(include=[np.number]).columns.tolist()) - set(number_max) - set(['sales_volume', 'stock_quantity', 'min_stock'])) 
not_numbers = read_data.select_dtypes(exclude=[np.number]).columns.tolist()

# %%
# Create rules for groupby
agg_rules = {
    'sales_volume': 'sum',
    'stock_quantity': 'last',
    'min_stock': 'min',
}

for col in number_max:
    agg_rules[col] = 'max'

for col in number_mean:
    agg_rules[col] = 'mean'

for col in not_numbers:
    agg_rules[col] = 'last'

# %%
# Group duplicated data
read_data = read_data.groupby(['received_date', 'product_id', 'supplier_id'], as_index=False).agg(agg_rules)
# .reset_index(drop=True)

# %%
# Confirm duplicates
read_data.duplicated(subset=['received_date', 'product_id', 'supplier_id'], keep=False).sum()
# Out:
# 0

# %%
# Reorder Columns for organization
read_data = read_data[order_columns]

# %%
# Sort the data by 'received_date' to ensure chronological order
read_data = read_data.sort_values(['received_date', 'product_id'], ascending=True).reset_index(drop=True)

# Split the data into two parts:
# - Data on/after May 10, 2025, for comparison/validation
# - Data before May 10, 2025, for training and analysis
compare_data = read_data[read_data['received_date'] >= '2025-05-10'].copy()
df = read_data[read_data['received_date'] < '2025-05-10'].copy()

# %%
# Check tha last few rows of the historical data
df.tail()
# Out:
#       received_date        lpo  in_season        product product_id  \
# 70714    2025-05-09 2025-05-03      False     Brown Rice  1961227|P
# 70715    2025-05-09 2025-05-03      False        Walnuts  1966948|P
# 70716    2025-05-09 2025-05-01      False     Peanut Oil  1979791|P
# 70717    2025-05-09 2025-04-29      False         Shrimp  1992397|P
# 70718    2025-05-09 2025-05-03      False  Ground Coffee  1994909|P
#
#           category     sub_category  shelf_life_days  maximum_days_on_sale  \
# 70714       Pantry    Grains & Rice            180.0                  60.0
# 70715       Pantry     Nuts & Seeds            180.0                  60.0
# 70716       Pantry  Oils & Vinegars            365.0                  90.0
# 70717  Fresh Foods          Seafood              2.0                   1.0
# 70718    Beverages           Coffee            180.0                  60.0
#
#       unit_of_measurement  supplier_rating                 supplier  \
# 70714                  lb              4.0  GrainWorld Distributors
# 70715                  lb              5.0           Nut & Seed Co.
# 70716                unit              4.0        Oil & Vinegar Co.
# 70717                  lb              5.0            Coastal Catch
# 70718                unit              1.0       BeverageSource Co.
#
#       supplier_id  distance_km    moq storage_recommendation  \
# 70714   1807382|S        150.0  200.0           Refrigerated
# 70715   1911483|S        125.0   55.0       Room Temperature
# 70716   1464761|S        120.0   80.0       Room Temperature
# 70717   1999523|S        220.0   25.0           Refrigerated
# 70718   1820500|S        110.0   70.0       Room Temperature
#
#       temperature_classification precipitation_classification  \
# 70714          Mild to Temperate             No precipitation
# 70715          Mild to Temperate             No precipitation
# 70716          Mild to Temperate             No precipitation
# 70717          Mild to Temperate             No precipitation
# 70718          Mild to Temperate             No precipitation
#
#        wind_classification weather_severity day_classification  is_holiday  \
# 70714  Calm / Light Breeze           Normal           Weekdays       False
# 70715  Calm / Light Breeze           Normal           Weekdays       False
# 70716  Calm / Light Breeze           Normal           Weekdays       False
# 70717  Calm / Light Breeze           Normal           Weekdays       False
# 70718  Calm / Light Breeze           Normal           Weekdays       False
#
#        is_weekend sales_demand  sales_volume  lead_time  min_stock  max_stock  \
# 70714       False       Normal           102          4        452        565
# 70715       False       Normal            10          3         64         80
# 70716       False       Normal            35          4        164        205
# 70717       False       Normal            45          5        150        180
# 70718       False       Normal            43          3        284        355
#
#        stock_quantity  delivery_lag expiration_status  \
# 70714              65             6              Safe
# 70715              71             6              Safe
# 70716             181             8              Safe
# 70717             172            10           Expired
# 70718             288             6              Safe
#
#        inventory_turnover_rate  doi_inventory_turnover
# 70714                27.197560                    37.0
# 70715                26.122325                    38.0
# 70716                25.860183                    39.0
# 70717                66.165180                    15.0
# 70718                26.853389                    37.0

# %%
# Check the first few rows of the comparison data
compare_data.head()
# Out:
#       received_date        lpo  in_season        product product_id  \
# 70719    2025-05-11 2025-05-08      False  Vegetable Oil  1021354|P
# 70720    2025-05-11 2025-05-05      False      Wild Rice  1048863|P
# 70721    2025-05-11 2025-05-02      False       Soy Milk  1049385|P
# 70722    2025-05-11 2025-05-05      False  Chocolate Bar  1068521|P
# 70723    2025-05-11 2025-05-07      False        Halibut  1086277|P
#
#                    category      sub_category  shelf_life_days  \
# 70719                Pantry   Oils & Vinegars            365.0
# 70720                Pantry     Grains & Rice            730.0
# 70721  Dairy & Alternatives  Plant-Based Milk              7.0
# 70722                Pantry            Snacks            365.0
# 70723           Fresh Foods           Seafood              2.0
#
#        maximum_days_on_sale unit_of_measurement  supplier_rating  \
# 70719                  90.0                unit              3.0
# 70720                 180.0                  lb              4.0
# 70721                   3.0                unit              3.0
# 70722                  90.0                unit              5.0
# 70723                   1.0                  lb              1.0
#
#                        supplier supplier_id  distance_km    moq  \
# 70719         Oil & Vinegar Co.   1464761|S        120.0   80.0
# 70720   GrainWorld Distributors   1807382|S        150.0  200.0
# 70721  Plant-Based Alternatives   1918650|S        105.0   60.0
# 70722          Chocolate Heaven   1806034|S        140.0   40.0
# 70723      OceanHarvest Seafood   1168079|S        180.0   40.0
#
#       storage_recommendation temperature_classification  \
# 70719       Room Temperature          Mild to Temperate
# 70720       Room Temperature          Mild to Temperate
# 70721           Refrigerated          Mild to Temperate
# 70722       Room Temperature          Mild to Temperate
# 70723           Refrigerated          Mild to Temperate
#
#       precipitation_classification  wind_classification weather_severity  \
# 70719             No precipitation  Calm / Light Breeze           Normal
# 70720             No precipitation  Calm / Light Breeze           Normal
# 70721             No precipitation  Calm / Light Breeze           Normal
# 70722             No precipitation  Calm / Light Breeze           Normal
# 70723             No precipitation  Calm / Light Breeze           Normal
#
#       day_classification  is_holiday  is_weekend sales_demand  sales_volume  \
# 70719             Sunday       False        True         High            69
# 70720             Sunday       False        True         High           189
# 70721             Sunday       False        True         High            29
# 70722             Sunday       False        True         High           363
# 70723             Sunday       False        True         High            47
#
#        lead_time  min_stock  max_stock  stock_quantity  delivery_lag  \
# 70719          5        164        205             199             3
# 70720          4        464        580             505             6
# 70721          4        244        305             342             9
# 70722          4        840       1050             842             6
# 70723          5        150        180             161             4
#
#       expiration_status  inventory_turnover_rate  doi_inventory_turnover
# 70719              Safe                26.798828                    37.0
# 70720              Safe                27.315464                    37.0
# 70721           Expired                26.679341                    38.0
# 70722              Safe                28.866901                    35.0
# 70723           Expired                21.952559                    46.0

# %% [markdown]
# Save Split DataFrame

# %%
# Save the processed DataFrame as a pickle file for efficient loading in future steps
df.to_parquet(data_path + '/data_for_train.parquet', engine="fastparquet")
compare_data.to_parquet(data_path + '/data_for_compare.parquet', engine="fastparquet")

# %%
# Return the shapes of both datasets to verify the split
df.shape, compare_data.shape
# Out:
# ((70719, 33), (8736, 33))

# %%
# Calculate the difference between expected and actual delivery time; positive means early, negative means delayed
df['delivery_time_variation'] = df['lead_time'] - df['delivery_lag']

# Add a description for the 'delivery_time_variation' column to clarify its meaning and interpretation
column_descriptions.update({
    'delivery_time_variation': 'Number of days between the expected delivery date and the actual delivery date. A positive value indicates early delivery, while a negative value indicates a delay.'
})

# %%
# Set 'received_date' column as the DataFrame index to enable time-based operations
df.set_index('received_date', inplace=True)

# %%
# Take information of Date
df['Year'] = df.index.get_level_values('received_date').year
df['Month'] = df.index.get_level_values('received_date').month
df['Day'] = df.index.get_level_values('received_date').day
df['DayOfYear'] = df.index.get_level_values('received_date').dayofyear
df['Weekday'] = df.index.get_level_values('received_date').weekday
df['QuarterOfYear'] = df.index.get_level_values('received_date').quarter
df['WeekOfYear'] = df.index.get_level_values('received_date').isocalendar().week.values

# %%
# Remove multi index
df = df.reset_index()
df
# Out:
#       received_date        lpo  in_season        product product_id  \
# 0        2022-12-09 2022-11-29       True           Lime  1019979|P
# 1        2022-12-09 2022-12-01      False    White Bread  1033235|P
# 2        2022-12-09 2022-12-07      False       Sardines  1093592|P
# 3        2022-12-09 2022-11-29      False        Avocado  1113134|P
# 4        2022-12-09 2022-12-03      False            Cod  1119767|P
# ...             ...        ...        ...            ...        ...
# 70714    2025-05-09 2025-05-03      False     Brown Rice  1961227|P
# 70715    2025-05-09 2025-05-03      False        Walnuts  1966948|P
# 70716    2025-05-09 2025-05-01      False     Peanut Oil  1979791|P
# 70717    2025-05-09 2025-04-29      False         Shrimp  1992397|P
# 70718    2025-05-09 2025-05-03      False  Ground Coffee  1994909|P
#
#           category     sub_category  shelf_life_days  maximum_days_on_sale  \
# 0      Fresh Foods           Fruits             21.0                   7.0
# 1           Bakery            Bread              5.0                   2.0
# 2      Fresh Foods          Seafood              2.0                   1.0
# 3      Fresh Foods           Fruits              7.0                   3.0
# 4      Fresh Foods          Seafood              2.0                   1.0
# ...            ...              ...              ...                   ...
# 70714       Pantry    Grains & Rice            180.0                  60.0
# 70715       Pantry     Nuts & Seeds            180.0                  60.0
# 70716       Pantry  Oils & Vinegars            365.0                  90.0
# 70717  Fresh Foods          Seafood              2.0                   1.0
# 70718    Beverages           Coffee            180.0                  60.0
#
#       unit_of_measurement  supplier_rating                 supplier  \
# 0                      lb              5.0         Lemon & Lime Co.
# 1                    unit              3.0         Bakery Fresh Co.
# 2                      lb              2.0     OceanHarvest Seafood
# 3                    unit              4.0           Avocado Avenue
# 4                      lb              1.0     OceanHarvest Seafood
# ...                   ...              ...                      ...
# 70714                  lb              4.0  GrainWorld Distributors
# 70715                  lb              5.0           Nut & Seed Co.
# 70716                unit              4.0        Oil & Vinegar Co.
# 70717                  lb              5.0            Coastal Catch
# 70718                unit              1.0       BeverageSource Co.
#
#       supplier_id  distance_km    moq storage_recommendation  \
# 0       1536622|S        190.0   35.0           Refrigerated
# 1       1644445|S         45.0   75.0       Room Temperature
# 2       1168079|S        180.0   40.0           Refrigerated
# 3       1840542|S        280.0   30.0       Room Temperature
# 4       1168079|S        180.0   40.0           Refrigerated
# ...           ...          ...    ...                    ...
# 70714   1807382|S        150.0  200.0           Refrigerated
# 70715   1911483|S        125.0   55.0       Room Temperature
# 70716   1464761|S        120.0   80.0       Room Temperature
# 70717   1999523|S        220.0   25.0           Refrigerated
# 70718   1820500|S        110.0   70.0       Room Temperature
#
#       temperature_classification precipitation_classification  \
# 0                           Warm             No precipitation
# 1                           Warm             No precipitation
# 2                           Warm             No precipitation
# 3                           Warm             No precipitation
# 4                           Warm             No precipitation
# ...                          ...                          ...
# 70714          Mild to Temperate             No precipitation
# 70715          Mild to Temperate             No precipitation
# 70716          Mild to Temperate             No precipitation
# 70717          Mild to Temperate             No precipitation
# 70718          Mild to Temperate             No precipitation
#
#           wind_classification weather_severity day_classification  is_holiday  \
# 0      Gentle to Fresh Breeze         Moderate           Weekdays       False
# 1      Gentle to Fresh Breeze         Moderate           Weekdays       False
# 2      Gentle to Fresh Breeze         Moderate           Weekdays       False
# 3      Gentle to Fresh Breeze         Moderate           Weekdays       False
# 4      Gentle to Fresh Breeze         Moderate           Weekdays       False
# ...                       ...              ...                ...         ...
# 70714     Calm / Light Breeze           Normal           Weekdays       False
# 70715     Calm / Light Breeze           Normal           Weekdays       False
# 70716     Calm / Light Breeze           Normal           Weekdays       False
# 70717     Calm / Light Breeze           Normal           Weekdays       False
# 70718     Calm / Light Breeze           Normal           Weekdays       False
#
#        is_weekend sales_demand  sales_volume  lead_time  min_stock  max_stock  \
# 0           False       Normal           526          7       3520       4224
# 1           False       Normal           688          3       2271       3028
# 2           False       Normal            33          5        155        186
# 3           False       Normal           718          7       5975       7170
# 4           False       Normal            45          6        150        180
# ...           ...          ...           ...        ...        ...        ...
# 70714       False       Normal           102          4        452        565
# 70715       False       Normal            10          3         64         80
# 70716       False       Normal            35          4        164        205
# 70717       False       Normal            45          5        150        180
# 70718       False       Normal            43          3        284        355
#
#        stock_quantity  delivery_lag expiration_status  \
# 0                5275            10           Nearing
# 1                2436             8           Expired
# 2                 155             2           Nearing
# 3                6677            10           Expired
# 4                 156             9           Expired
# ...               ...           ...               ...
# 70714              65             6              Safe
# 70715              71             6              Safe
# 70716             181             8              Safe
# 70717             172            10           Expired
# 70718             288             6              Safe
#
#        inventory_turnover_rate  doi_inventory_turnover  \
# 0                    21.494078                    47.0
# 1                    35.607450                    28.0
# 2                    22.882402                    44.0
# 3                    42.740888                    23.0
# 4                    44.152735                    23.0
# ...                        ...                     ...
# 70714                27.197560                    37.0
# 70715                26.122325                    38.0
# 70716                25.860183                    39.0
# 70717                66.165180                    15.0
# 70718                26.853389                    37.0
#
#        delivery_time_variation  Year  Month  Day  DayOfYear  Weekday  \
# 0                           -3  2022     12    9        343        4
# 1                           -5  2022     12    9        343        4
# 2                            3  2022     12    9        343        4
# 3                           -3  2022     12    9        343        4
# 4                           -3  2022     12    9        343        4
# ...                        ...   ...    ...  ...        ...      ...
# 70714                       -2  2025      5    9        129        4
# 70715                       -3  2025      5    9        129        4
# 70716                       -4  2025      5    9        129        4
# 70717                       -5  2025      5    9        129        4
# 70718                       -3  2025      5    9        129        4
#
#        QuarterOfYear  WeekOfYear
# 0                  4          49
# 1                  4          49
# 2                  4          49
# 3                  4          49
# 4                  4          49
# ...              ...         ...
# 70714              2          19
# 70715              2          19
# 70716              2          19
# 70717              2          19
# 70718              2          19
#
# [70719 rows x 41 columns]

# %%
def calculate_std_demand_lead_time(df, product_col='product', sales_col='sales_volume', lead_col='delivery_lag'):
    """
    Calculate the standard deviation of demand during lead time for each product.

    Parameters:
    - df (DataFrame): Input DataFrame containing sales and delivery data.
    - product_col (str): Column name representing the product identifier.
    - sales_col (str): Column name representing daily sales volume.
    - lead_col (str): Column name representing delivery lead time (in days).

    Returns:
    - DataFrame: Original DataFrame with additional columns:
        - 'avg_daily_sales': Average daily sales per product.
        - 'std_daily_sales': Standard deviation of daily sales per product.
        - 'avg_daily_lag': Average delivery lead time per product.
        - 'std_daily_lag': Standard deviation of delivery lead time per product.
        - 'std_demand_lead_time': Standard deviation of demand during lead time per product.
    """

    # Calculate the average daily sales for each product
    df['avg_daily_sales'] = df.groupby(product_col)[sales_col].transform('mean')

    # Calculate the standard deviation of daily sales for each product
    df['std_daily_sales'] = df.groupby(product_col)[sales_col].transform('std')

    # Calculate the average delivery lead time for each product
    df['avg_daily_lag'] = df.groupby(product_col)[lead_col].transform('mean')

    # Calculate the standard deviation of delivery lead time for each product
    df['std_daily_lag'] = df.groupby(product_col)[lead_col].transform('std')

    # Compute the standard deviation of demand during lead time using the formula:
    # sqrt(LeadTimeAvg * SalesStd^2 + SalesAvg^2 * LeadTimeStd^2)
    df['std_demand_lead_time'] = np.sqrt(
        (df['avg_daily_lag'] * (df['std_daily_sales'] ** 2)) +
        ((df['avg_daily_sales'] ** 2) * (df['std_daily_lag'] ** 2))
    )

    return df

# %%
# Apply the function to compute demand variability during lead time and update the DataFrame with new metrics
df = calculate_std_demand_lead_time(df=df)

# %% [markdown]
# ---
#
# ### **Service Level Factor (Z) Based on the Standard Normal Distribution**
#
# The Service Level Factor (Z) is obtained from a standard normal distribution table.
#
# - **80% Service Level**: Z = 0.84
# - **85% Service Level**: Z = 1.04
# - **90% Service Level**: Z = 1.28
# - **95% Service Level**: Z = 1.64
# - **98% Service Level**: Z = 2.05
# - **99% Service Level**: Z = 2.33
#
# ---

# %%
# Set the Z factor for a 95% service level
Z = 1.64

# Calculate the Safety Stock
df['safety_stock'] = (Z * df['std_demand_lead_time'])

# Add description for the 'safety_stock' column to clarify its role in inventory management
column_descriptions.update({'safety_stock': 'Extra inventory buffer maintained to protect against uncertainties in demand and delivery lead time.'})

# %%
df.select_dtypes(np.number)[:2]
# Out:
#    shelf_life_days  maximum_days_on_sale  supplier_rating  distance_km   moq  \
# 0             21.0                   7.0              5.0        190.0  35.0
# 1              5.0                   2.0              3.0         45.0  75.0
#
#    sales_volume  lead_time  min_stock  max_stock  stock_quantity  \
# 0           526          7       3520       4224            5275
# 1           688          3       2271       3028            2436
#
#    delivery_lag  inventory_turnover_rate  doi_inventory_turnover  \
# 0            10                21.494078                    47.0
# 1             8                35.607450                    28.0
#
#    delivery_time_variation  Year  Month  Day  DayOfYear  Weekday  \
# 0                       -3  2022     12    9        343        4
# 1                       -5  2022     12    9        343        4
#
#    QuarterOfYear  WeekOfYear  avg_daily_sales  std_daily_sales  avg_daily_lag  \
# 0              4          49       863.320809       490.360150       6.632948
# 1              4          49       965.951009       540.321774       6.423631
#
#    std_daily_lag  std_demand_lead_time  safety_stock
# 0       2.520860           2516.196241   4126.561835
# 1       2.540269           2810.049280   4608.480819

# %%
# Calculates the Reorder Point (ROP) for each product.
df['rop'] = (df['avg_daily_sales'] * df['delivery_lag']) + df['safety_stock']

# Define description for 'rop' (Reorder Point) to indicate when replenishment should be triggered
column_descriptions.update({'rop': 'ROP is the inventory level at which a new order should be placed to avoid stock outs.'})

# %%
# Create Variable Reorder Point / Sales Volume
df['reorder_point_coverage'] = df['rop'] / df['avg_daily_sales']

# Add description for 'reorder_point_coverage' to indicate how many days of demand the ROP supports
column_descriptions.update({'reorder_point_coverage': 'Number of days of demand that the reorder point (ROP) can cover'})

# %%
# Calculates the reorder quantity as the average sales per product multiplied by the lead time
df['reorder_quantity'] = (df.groupby('product')['sales_volume'].transform(np.mean) * df['lead_time']).astype(int)

# Add description for 'reorder_quantity' to define the optimal quantity to order when replenishing stock
column_descriptions.update({'reorder_quantity': 'Optimal number of units to order once inventory reaches the reorder point, based on expected demand during lead time.'})

# %%
# Create Variable Reorder Level, Reorder Quantity and Inventory Turnover Rate
df['reorder_point_quantity_turnover'] = (df['rop'] - df['reorder_quantity']) / df['inventory_turnover_rate']

# Add description for 'reorder_point_quantity_turnover' to explain how quickly the buffer stock is depleted
column_descriptions.update({'reorder_point_quantity_turnover': 'Rate at which the buffer between the reorder level and reorder quantity is consumed'})

# %%
# Transform string distance_km in integer for include in train models
df['distance_km'] = df['distance_km'].astype(int)

# %%
df
# Out:
#       received_date        lpo  in_season        product product_id  \
# 0        2022-12-09 2022-11-29       True           Lime  1019979|P
# 1        2022-12-09 2022-12-01      False    White Bread  1033235|P
# 2        2022-12-09 2022-12-07      False       Sardines  1093592|P
# 3        2022-12-09 2022-11-29      False        Avocado  1113134|P
# 4        2022-12-09 2022-12-03      False            Cod  1119767|P
# ...             ...        ...        ...            ...        ...
# 70714    2025-05-09 2025-05-03      False     Brown Rice  1961227|P
# 70715    2025-05-09 2025-05-03      False        Walnuts  1966948|P
# 70716    2025-05-09 2025-05-01      False     Peanut Oil  1979791|P
# 70717    2025-05-09 2025-04-29      False         Shrimp  1992397|P
# 70718    2025-05-09 2025-05-03      False  Ground Coffee  1994909|P
#
#           category     sub_category  shelf_life_days  maximum_days_on_sale  \
# 0      Fresh Foods           Fruits             21.0                   7.0
# 1           Bakery            Bread              5.0                   2.0
# 2      Fresh Foods          Seafood              2.0                   1.0
# 3      Fresh Foods           Fruits              7.0                   3.0
# 4      Fresh Foods          Seafood              2.0                   1.0
# ...            ...              ...              ...                   ...
# 70714       Pantry    Grains & Rice            180.0                  60.0
# 70715       Pantry     Nuts & Seeds            180.0                  60.0
# 70716       Pantry  Oils & Vinegars            365.0                  90.0
# 70717  Fresh Foods          Seafood              2.0                   1.0
# 70718    Beverages           Coffee            180.0                  60.0
#
#       unit_of_measurement  supplier_rating                 supplier  \
# 0                      lb              5.0         Lemon & Lime Co.
# 1                    unit              3.0         Bakery Fresh Co.
# 2                      lb              2.0     OceanHarvest Seafood
# 3                    unit              4.0           Avocado Avenue
# 4                      lb              1.0     OceanHarvest Seafood
# ...                   ...              ...                      ...
# 70714                  lb              4.0  GrainWorld Distributors
# 70715                  lb              5.0           Nut & Seed Co.
# 70716                unit              4.0        Oil & Vinegar Co.
# 70717                  lb              5.0            Coastal Catch
# 70718                unit              1.0       BeverageSource Co.
#
#       supplier_id  distance_km    moq storage_recommendation  \
# 0       1536622|S          190   35.0           Refrigerated
# 1       1644445|S           45   75.0       Room Temperature
# 2       1168079|S          180   40.0           Refrigerated
# 3       1840542|S          280   30.0       Room Temperature
# 4       1168079|S          180   40.0           Refrigerated
# ...           ...          ...    ...                    ...
# 70714   1807382|S          150  200.0           Refrigerated
# 70715   1911483|S          125   55.0       Room Temperature
# 70716   1464761|S          120   80.0       Room Temperature
# 70717   1999523|S          220   25.0           Refrigerated
# 70718   1820500|S          110   70.0       Room Temperature
#
#       temperature_classification precipitation_classification  \
# 0                           Warm             No precipitation
# 1                           Warm             No precipitation
# 2                           Warm             No precipitation
# 3                           Warm             No precipitation
# 4                           Warm             No precipitation
# ...                          ...                          ...
# 70714          Mild to Temperate             No precipitation
# 70715          Mild to Temperate             No precipitation
# 70716          Mild to Temperate             No precipitation
# 70717          Mild to Temperate             No precipitation
# 70718          Mild to Temperate             No precipitation
#
#           wind_classification weather_severity day_classification  is_holiday  \
# 0      Gentle to Fresh Breeze         Moderate           Weekdays       False
# 1      Gentle to Fresh Breeze         Moderate           Weekdays       False
# 2      Gentle to Fresh Breeze         Moderate           Weekdays       False
# 3      Gentle to Fresh Breeze         Moderate           Weekdays       False
# 4      Gentle to Fresh Breeze         Moderate           Weekdays       False
# ...                       ...              ...                ...         ...
# 70714     Calm / Light Breeze           Normal           Weekdays       False
# 70715     Calm / Light Breeze           Normal           Weekdays       False
# 70716     Calm / Light Breeze           Normal           Weekdays       False
# 70717     Calm / Light Breeze           Normal           Weekdays       False
# 70718     Calm / Light Breeze           Normal           Weekdays       False
#
#        is_weekend sales_demand  sales_volume  lead_time  min_stock  max_stock  \
# 0           False       Normal           526          7       3520       4224
# 1           False       Normal           688          3       2271       3028
# 2           False       Normal            33          5        155        186
# 3           False       Normal           718          7       5975       7170
# 4           False       Normal            45          6        150        180
# ...           ...          ...           ...        ...        ...        ...
# 70714       False       Normal           102          4        452        565
# 70715       False       Normal            10          3         64         80
# 70716       False       Normal            35          4        164        205
# 70717       False       Normal            45          5        150        180
# 70718       False       Normal            43          3        284        355
#
#        stock_quantity  delivery_lag expiration_status  \
# 0                5275            10           Nearing
# 1                2436             8           Expired
# 2                 155             2           Nearing
# 3                6677            10           Expired
# 4                 156             9           Expired
# ...               ...           ...               ...
# 70714              65             6              Safe
# 70715              71             6              Safe
# 70716             181             8              Safe
# 70717             172            10           Expired
# 70718             288             6              Safe
#
#        inventory_turnover_rate  doi_inventory_turnover  \
# 0                    21.494078                    47.0
# 1                    35.607450                    28.0
# 2                    22.882402                    44.0
# 3                    42.740888                    23.0
# 4                    44.152735                    23.0
# ...                        ...                     ...
# 70714                27.197560                    37.0
# 70715                26.122325                    38.0
# 70716                25.860183                    39.0
# 70717                66.165180                    15.0
# 70718                26.853389                    37.0
#
#        delivery_time_variation  Year  Month  Day  DayOfYear  Weekday  \
# 0                           -3  2022     12    9        343        4
# 1                           -5  2022     12    9        343        4
# 2                            3  2022     12    9        343        4
# 3                           -3  2022     12    9        343        4
# 4                           -3  2022     12    9        343        4
# ...                        ...   ...    ...  ...        ...      ...
# 70714                       -2  2025      5    9        129        4
# 70715                       -3  2025      5    9        129        4
# 70716                       -4  2025      5    9        129        4
# 70717                       -5  2025      5    9        129        4
# 70718                       -3  2025      5    9        129        4
#
#        QuarterOfYear  WeekOfYear  avg_daily_sales  std_daily_sales  \
# 0                  4          49       863.320809       490.360150
# 1                  4          49       965.951009       540.321774
# 2                  4          49        40.364179        25.390222
# 3                  4          49      1542.605183       988.380985
# 4                  4          49        35.506550        19.776953
# ...              ...         ...              ...              ...
# 70714              2          19       141.690544        79.620518
# 70715              2          19        19.881098        11.143814
# 70716              2          19        48.765957        27.841613
# 70717              2          19        37.756972        21.928387
# 70718              2          19        87.292135        50.179498
#
#        avg_daily_lag  std_daily_lag  std_demand_lead_time  safety_stock  \
# 0           6.632948       2.520860           2516.196241   4126.561835
# 1           6.423631       2.540269           2810.049280   4608.480819
# 2           6.113433       2.657995            124.305179    203.860494
# 3           6.371951       2.661929           4804.840326   7879.938134
# 4           6.276565       2.550211            103.218676    169.278629
# ...              ...            ...                   ...           ...
# 70714       6.441261       2.543894            413.225134    677.689220
# 70715       6.387195       2.513466             57.360600     94.071384
# 70716       6.197568       2.538819            141.889003    232.697965
# 70717       6.409363       2.608131            113.045638    185.394846
# 70718       6.401685       2.549542            256.222665    420.205171
#
#                 rop  reorder_point_coverage  reorder_quantity  \
# 0      12759.769928               14.779871              6043
# 1      12336.088888               12.770926              2897
# 2        284.588852                7.050530               201
# 3      23305.989963               15.108202             10798
# 4        488.837581               13.767532               213
# ...             ...                     ...               ...
# 70714   1527.832487               10.782882               566
# 70715    213.357969               10.731700                59
# 70716    622.825624               12.771730               195
# 70717    562.964567               14.910215               188
# 70718    943.957980               10.813780               261
#
#        reorder_point_quantity_turnover
# 0                           312.493985
# 1                           265.087469
# 2                             3.652975
# 3                           292.646935
# 4                             6.247350
# ...                                ...
# 70714                        35.364661
# 70715                         5.909044
# 70716                        16.543797
# 70717                         5.667098
# 70718                        25.432841
#
# [70719 rows x 51 columns]

# %%
# Drop non-essential or redundant columns from the time series DataFrame to streamline analysis
columns_dropped = df.select_dtypes(exclude=[np.number, 'datetime', bool]).columns.tolist()

df.drop(columns=columns_dropped, inplace=True)

# %%
# Calculate the correlation matrix for all numeric columns
correlation_matrix = df.corr()

# %%
corr1 = correlation_matrix[correlation_matrix >= 0.7].replace(1.0, np.nan).dropna(how='all', axis=1)
corr1.dropna(how='all').replace(np.nan, '')
# Out:
#                                 received_date       lpo shelf_life_days  \
# received_date                                  0.999949
# lpo                                  0.999949
# shelf_life_days
# maximum_days_on_sale                                           0.900836
# is_weekend
# sales_volume
# min_stock
# max_stock
# stock_quantity
# delivery_lag
# Year                                 0.916281   0.91626
# Month
# DayOfYear
# Weekday
# QuarterOfYear
# WeekOfYear
# avg_daily_sales
# std_daily_sales
# std_demand_lead_time
# safety_stock
# rop
# reorder_point_coverage
# reorder_quantity
# reorder_point_quantity_turnover
#
#                                 maximum_days_on_sale is_weekend sales_volume  \
# received_date
# lpo
# shelf_life_days                             0.900836
# maximum_days_on_sale
# is_weekend
# sales_volume
# min_stock                                                           0.745612
# max_stock                                                           0.752773
# stock_quantity
# delivery_lag
# Year
# Month
# DayOfYear
# Weekday                                                0.789994
# QuarterOfYear
# WeekOfYear
# avg_daily_sales                                                     0.768107
# std_daily_sales                                                     0.766157
# std_demand_lead_time                                                0.767724
# safety_stock                                                        0.767724
# rop                                                                 0.768248
# reorder_point_coverage
# reorder_quantity                                                    0.774728
# reorder_point_quantity_turnover
#
#                                 min_stock max_stock stock_quantity  \
# received_date
# lpo
# shelf_life_days
# maximum_days_on_sale
# is_weekend
# sales_volume                     0.745612  0.752773
# min_stock                                  0.999028       0.906716
# max_stock                        0.999028                 0.907104
# stock_quantity                   0.906716  0.907104
# delivery_lag
# Year
# Month
# DayOfYear
# Weekday
# QuarterOfYear
# WeekOfYear
# avg_daily_sales                  0.970032  0.979408       0.886256
# std_daily_sales                  0.967024  0.976502       0.883884
# std_demand_lead_time             0.969973  0.979263       0.886201
# safety_stock                     0.969973  0.979263       0.886201
# rop                              0.926481  0.935444       0.846213
# reorder_point_coverage
# reorder_quantity                 0.974399  0.973706       0.883035
# reorder_point_quantity_turnover  0.743888  0.750908
#
#                                 delivery_lag      Year     Month DayOfYear  \
# received_date                                 0.916281
# lpo                                            0.91626
# shelf_life_days
# maximum_days_on_sale
# is_weekend
# sales_volume
# min_stock
# max_stock
# stock_quantity
# delivery_lag
# Year
# Month                                                              0.99677
# DayOfYear                                                0.99677
# Weekday
# QuarterOfYear                                           0.973042  0.970069
# WeekOfYear                                              0.978855  0.980612
# avg_daily_sales
# std_daily_sales
# std_demand_lead_time
# safety_stock
# rop
# reorder_point_coverage              0.999025
# reorder_quantity
# reorder_point_quantity_turnover
#
#                                   Weekday QuarterOfYear WeekOfYear  \
# received_date
# lpo
# shelf_life_days
# maximum_days_on_sale
# is_weekend                       0.789994
# sales_volume
# min_stock
# max_stock
# stock_quantity
# delivery_lag
# Year
# Month                                          0.973042   0.978855
# DayOfYear                                      0.970069   0.980612
# Weekday
# QuarterOfYear                                             0.954981
# WeekOfYear                                     0.954981
# avg_daily_sales
# std_daily_sales
# std_demand_lead_time
# safety_stock
# rop
# reorder_point_coverage
# reorder_quantity
# reorder_point_quantity_turnover
#
#                                 avg_daily_sales std_daily_sales  \
# received_date
# lpo
# shelf_life_days
# maximum_days_on_sale
# is_weekend
# sales_volume                           0.768107        0.766157
# min_stock                              0.970032        0.967024
# max_stock                              0.979408        0.976502
# stock_quantity                         0.886256        0.883884
# delivery_lag
# Year
# Month
# DayOfYear
# Weekday
# QuarterOfYear
# WeekOfYear
# avg_daily_sales                                        0.997462
# std_daily_sales                        0.997462
# std_demand_lead_time                   0.999502        0.998683
# safety_stock                           0.999502        0.998683
# rop                                     0.95532        0.953669
# reorder_point_coverage
# reorder_quantity                       0.948004        0.945424
# reorder_point_quantity_turnover        0.767669        0.761179
#
#                                 std_demand_lead_time safety_stock       rop  \
# received_date
# lpo
# shelf_life_days
# maximum_days_on_sale
# is_weekend
# sales_volume                                0.767724     0.767724  0.768248
# min_stock                                   0.969973     0.969973  0.926481
# max_stock                                   0.979263     0.979263  0.935444
# stock_quantity                              0.886201     0.886201  0.846213
# delivery_lag
# Year
# Month
# DayOfYear
# Weekday
# QuarterOfYear
# WeekOfYear
# avg_daily_sales                             0.999502     0.999502   0.95532
# std_daily_sales                             0.998683     0.998683  0.953669
# std_demand_lead_time                                          1.0  0.955242
# safety_stock                                     1.0               0.955242
# rop                                         0.955242     0.955242
# reorder_point_coverage
# reorder_quantity                            0.948067     0.948067  0.908571
# reorder_point_quantity_turnover             0.767194     0.767194  0.861442
#
#                                 reorder_point_coverage reorder_quantity  \
# received_date
# lpo
# shelf_life_days
# maximum_days_on_sale
# is_weekend
# sales_volume                                                   0.774728
# min_stock                                                      0.974399
# max_stock                                                      0.973706
# stock_quantity                                                 0.883035
# delivery_lag                                  0.999025
# Year
# Month
# DayOfYear
# Weekday
# QuarterOfYear
# WeekOfYear
# avg_daily_sales                                                0.948004
# std_daily_sales                                                0.945424
# std_demand_lead_time                                           0.948067
# safety_stock                                                   0.948067
# rop                                                            0.908571
# reorder_point_coverage
# reorder_quantity
# reorder_point_quantity_turnover
#
#                                 reorder_point_quantity_turnover
# received_date
# lpo
# shelf_life_days
# maximum_days_on_sale
# is_weekend
# sales_volume
# min_stock                                              0.743888
# max_stock                                              0.750908
# stock_quantity
# delivery_lag
# Year
# Month
# DayOfYear
# Weekday
# QuarterOfYear
# WeekOfYear
# avg_daily_sales                                        0.767669
# std_daily_sales                                        0.761179
# std_demand_lead_time                                   0.767194
# safety_stock                                           0.767194
# rop                                                    0.861442
# reorder_point_coverage
# reorder_quantity
# reorder_point_quantity_turnover

# %%
# Hide the top half of the matrix to avoid repeating values
mask = np.tril(np.ones(correlation_matrix.shape), k=-1)
masked_corr = correlation_matrix.where(mask == 1)

# Create a heatmap visualization of the correlation matrix
fig_corr = px.imshow(masked_corr,
                    title='Correlation Matrix - Numeric Variables',
                    color_continuous_scale='RdBu_r',  # Red-Blue reversed color scale
                    aspect="auto",                   # Automatic aspect ratio
                    text_auto=False,                 # Display correlation values on cells
                    zmin=-1, zmax=1)                 # Fix color scale from -1 to +1

# Adjust the figure dimensions
fig_corr.update_layout(width=1200, height=1200)

# Display the interactive heatmap
fig_corr.show()

# %%
# Displays a concise summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70719 entries, 0 to 70718
# Data columns (total 36 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   received_date                    70719 non-null  datetime64[ns]
#  1   lpo                              70719 non-null  datetime64[ns]
#  2   in_season                        70719 non-null  bool
#  3   shelf_life_days                  70719 non-null  float64
#  4   maximum_days_on_sale             70719 non-null  float64
#  5   supplier_rating                  70719 non-null  float64
#  6   distance_km                      70719 non-null  int64
#  7   moq                              70719 non-null  float64
#  8   is_holiday                       70719 non-null  bool
#  9   is_weekend                       70719 non-null  bool
#  10  sales_volume                     70719 non-null  int64
#  11  lead_time                        70719 non-null  int64
#  12  min_stock                        70719 non-null  int64
#  13  max_stock                        70719 non-null  int64
#  14  stock_quantity                   70719 non-null  int64
#  15  delivery_lag                     70719 non-null  int64
#  16  inventory_turnover_rate          70719 non-null  float64
#  17  doi_inventory_turnover           70719 non-null  float64
#  18  delivery_time_variation          70719 non-null  int64
#  19  Year                             70719 non-null  int32
#  20  Month                            70719 non-null  int32
#  21  Day                              70719 non-null  int32
#  22  DayOfYear                        70719 non-null  int32
#  23  Weekday                          70719 non-null  int32
#  24  QuarterOfYear                    70719 non-null  int32
#  25  WeekOfYear                       70719 non-null  UInt32
#  26  avg_daily_sales                  70719 non-null  float64
#  27  std_daily_sales                  70719 non-null  float64
#  28  avg_daily_lag                    70719 non-null  float64
#  29  std_daily_lag                    70719 non-null  float64
#  30  std_demand_lead_time             70719 non-null  float64
#  31  safety_stock                     70719 non-null  float64
#  32  rop                              70719 non-null  float64
#  33  reorder_point_coverage           70719 non-null  float64
#  34  reorder_quantity                 70719 non-null  int64
#  35  reorder_point_quantity_turnover  70719 non-null  float64
# dtypes: UInt32(1), bool(3), datetime64[ns](2), float64(15), int32(6), int64(9)
# memory usage: 16.2 MB
