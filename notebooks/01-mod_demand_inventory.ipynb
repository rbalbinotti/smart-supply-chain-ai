# %% [markdown]
# Módulo 01
# # Previsão de Demanda e Otimização de Estoque
#
# Objetivos:
# - Redução do excesso de estoque em 20% e do índice de ruptura em 15%, dentro de 6 meses.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import os
import plotly.express as px
import plotly.io as pio

from smart_supply_chain_ai.data_processing import get_data

import warnings
warnings.filterwarnings('ignore')

# Define plotly template
pio.templates.default = "plotly_white"

# Pandas show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Get Data

# %%
# Paths
raw_data_path = os.path.join('../data', 'raw')
processed_data_path = os.path.join('../data', 'processed')

# %%
# link for data - [USER] [DATASET_NAME]
module_one = "salahuddinahmedshuvo/grocery-inventory-and-sales-dataset"
# Download Data and Unzip 
get_data.download_kaggle_dataset(module_one, raw_data_path)
# Out:
# Starting the download of dataset 'salahuddinahmedshuvo/grocery-inventory-and-sales-dataset' from Kaggle...
# Dataset URL: https://www.kaggle.com/datasets/salahuddinahmedshuvo/grocery-inventory-and-sales-dataset
# Download, unzipping, and cleanup complete! The dataset was saved to: ../data/raw

# %%
# Load data
df_raw = pd.read_csv(raw_data_path + '/Grocery_Inventory_and_Sales_Dataset.csv')

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product_ID               990 non-null    object
#  1   Product_Name             990 non-null    object
#  2   Catagory                 989 non-null    object
#  3   Supplier_ID              990 non-null    object
#  4   Supplier_Name            990 non-null    object
#  5   Stock_Quantity           990 non-null    int64
#  6   Reorder_Level            990 non-null    int64
#  7   Reorder_Quantity         990 non-null    int64
#  8   Unit_Price               990 non-null    object
#  9   Date_Received            990 non-null    object
#  10  Last_Order_Date          990 non-null    object
#  11  Expiration_Date          990 non-null    object
#  12  Warehouse_Location       990 non-null    object
#  13  Sales_Volume             990 non-null    int64
#  14  Inventory_Turnover_Rate  990 non-null    int64
#  15  Status                   990 non-null    object
# dtypes: int64(5), object(11)
# memory usage: 123.9+ KB

# %% [markdown]
#     • Expiration_Date: A data de validade do produto.
#     • Last_Order_Date: A última data em que o produto foi encomendado.
#     • Warehouse_Location: O local de armazenamento do produto.
#     • Sales_Volume: Volume total de unidades vendidas.
#     • Inventory_Turnover_Rate: Taxa na qual o produto vende e é reabastecido.
#     • Status: Status atual (por exemplo, Ativo, Descontinuado, Em falta).

# %%
# make a copy
df = df_raw.copy()

# %%
df.rename(columns={"Catagory": "Category"}, inplace=True)

# %%
df[df['Category'].isna()]
# Out:
#       Product_ID Product_Name Category  Supplier_ID Supplier_Name  \
# 685  10-378-9729      Cabbage      NaN  83-941-9620         Rooxo
#
#      Stock_Quantity  Reorder_Level  Reorder_Quantity Unit_Price Date_Received  \
# 685              69             21                68    $66.55     12/23/2024
#
#     Last_Order_Date Expiration_Date  Warehouse_Location  Sales_Volume  \
# 685      11/26/2024       9/21/2024  2 Butterfield Pass            36
#
#      Inventory_Turnover_Rate        Status
# 685                       35  Discontinued

# %%
df.Category.unique()
# Out:
# array(['Grains & Pulses', 'Beverages', 'Fruits & Vegetables',
#        'Oils & Fats', 'Dairy', 'Bakery', 'Seafood', nan], dtype=object)

# %% [markdown]
# ### Missing Values

# %%
# I decided to categorize cabbage under 'Fruits & Vegetables' after researching online. 
df = df.fillna('Fruits & Vegetables')

# %% [markdown]
# ### Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product_ID               990 non-null    object
#  1   Product_Name             990 non-null    object
#  2   Category                 990 non-null    object
#  3   Supplier_ID              990 non-null    object
#  4   Supplier_Name            990 non-null    object
#  5   Stock_Quantity           990 non-null    int64
#  6   Reorder_Level            990 non-null    int64
#  7   Reorder_Quantity         990 non-null    int64
#  8   Unit_Price               990 non-null    object
#  9   Date_Received            990 non-null    object
#  10  Last_Order_Date          990 non-null    object
#  11  Expiration_Date          990 non-null    object
#  12  Warehouse_Location       990 non-null    object
#  13  Sales_Volume             990 non-null    int64
#  14  Inventory_Turnover_Rate  990 non-null    int64
#  15  Status                   990 non-null    object
# dtypes: int64(5), object(11)
# memory usage: 123.9+ KB

# %%
df.head()
# Out:
#     Product_ID     Product_Name             Category  Supplier_ID  \
# 0  29-205-1132       Sushi Rice      Grains & Pulses  38-037-1699
# 1  40-681-9981   Arabica Coffee            Beverages  54-470-2479
# 2  06-955-3428       Black Rice      Grains & Pulses  54-031-2945
# 3  71-594-6552  Long Grain Rice      Grains & Pulses  63-492-7603
# 4  57-437-1828             Plum  Fruits & Vegetables  54-226-4308
#
#   Supplier_Name  Stock_Quantity  Reorder_Level  Reorder_Quantity Unit_Price  \
# 0     Jaxnation              22             72                70     $4.50
# 1       Feedmix              45             77                 2    $20.00
# 2        Vinder              30             38                83     $6.00
# 3    Brightbean              12             59                62     $1.50
# 4    Topicstorm              37             30                74     $4.00
#
#   Date_Received Last_Order_Date Expiration_Date      Warehouse_Location  \
# 0     8/16/2024       6/29/2024       9/19/2024        48 Del Sol Trail
# 1     11/1/2024       5/29/2024        5/8/2024            36 3rd Place
# 2      8/3/2024       6/10/2024       9/22/2024       3296 Walton Court
# 3     12/8/2024       2/19/2025       4/17/2024  3 Westerfield Crossing
# 4      7/3/2024      10/11/2024       10/5/2024    15068 Scoville Court
#
#    Sales_Volume  Inventory_Turnover_Rate        Status
# 0            32                       19  Discontinued
# 1            85                        1  Discontinued
# 2            31                       34   Backordered
# 3            95                       99        Active
# 4            62                       25   Backordered

# %%
# Create category columns
cat_columns = ['Category', 'Status']
df[cat_columns] = df[cat_columns].astype('category')

# %%
# create date columns
date_columns = ['Date_Received', 'Last_Order_Date', 'Expiration_Date']
df[date_columns] = df[date_columns].apply(pd.to_datetime, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product_ID               990 non-null    object
#  1   Product_Name             990 non-null    object
#  2   Category                 990 non-null    category
#  3   Supplier_ID              990 non-null    object
#  4   Supplier_Name            990 non-null    object
#  5   Stock_Quantity           990 non-null    int64
#  6   Reorder_Level            990 non-null    int64
#  7   Reorder_Quantity         990 non-null    int64
#  8   Unit_Price               990 non-null    object
#  9   Date_Received            990 non-null    datetime64[ns]
#  10  Last_Order_Date          990 non-null    datetime64[ns]
#  11  Expiration_Date          990 non-null    datetime64[ns]
#  12  Warehouse_Location       990 non-null    object
#  13  Sales_Volume             990 non-null    int64
#  14  Inventory_Turnover_Rate  990 non-null    int64
#  15  Status                   990 non-null    category
# dtypes: category(2), datetime64[ns](3), int64(5), object(6)
# memory usage: 110.8+ KB

# %%
# Remove "$" from price
df['Unit_Price'] = df['Unit_Price'].str.replace('$', '').astype('float')

# %%
df.head()
# Out:
#     Product_ID     Product_Name             Category  Supplier_ID  \
# 0  29-205-1132       Sushi Rice      Grains & Pulses  38-037-1699
# 1  40-681-9981   Arabica Coffee            Beverages  54-470-2479
# 2  06-955-3428       Black Rice      Grains & Pulses  54-031-2945
# 3  71-594-6552  Long Grain Rice      Grains & Pulses  63-492-7603
# 4  57-437-1828             Plum  Fruits & Vegetables  54-226-4308
#
#   Supplier_Name  Stock_Quantity  Reorder_Level  Reorder_Quantity  Unit_Price  \
# 0     Jaxnation              22             72                70         4.5
# 1       Feedmix              45             77                 2        20.0
# 2        Vinder              30             38                83         6.0
# 3    Brightbean              12             59                62         1.5
# 4    Topicstorm              37             30                74         4.0
#
#   Date_Received Last_Order_Date Expiration_Date      Warehouse_Location  \
# 0    2024-08-16      2024-06-29      2024-09-19        48 Del Sol Trail
# 1    2024-11-01      2024-05-29      2024-05-08            36 3rd Place
# 2    2024-08-03      2024-06-10      2024-09-22       3296 Walton Court
# 3    2024-12-08      2025-02-19      2024-04-17  3 Westerfield Crossing
# 4    2024-07-03      2024-10-11      2024-10-05    15068 Scoville Court
#
#    Sales_Volume  Inventory_Turnover_Rate        Status
# 0            32                       19  Discontinued
# 1            85                        1  Discontinued
# 2            31                       34   Backordered
# 3            95                       99        Active
# 4            62                       25   Backordered

# %%
df['Product_ID'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Supplier_ID'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## EDA - Exploratory Data Analysis

# %%
# Numeric columns statistics
df.describe(exclude=['datetime', 'object', 'category'])
# Out:
#        Stock_Quantity  Reorder_Level  Reorder_Quantity  Unit_Price  \
# count      990.000000     990.000000        990.000000  990.000000
# mean        55.609091      51.215152         51.913131    5.924192
# std         26.300775      29.095241         29.521059    6.491280
# min         10.000000       1.000000          1.000000    0.200000
# 25%         33.000000      25.250000         25.000000    2.500000
# 50%         56.000000      53.000000         54.000000    4.225000
# 75%         79.000000      77.000000         77.000000    7.000000
# max        100.000000     100.000000        100.000000   98.430000
#
#        Sales_Volume  Inventory_Turnover_Rate
# count    990.000000               990.000000
# mean      58.925253                50.150505
# std       23.002318                28.798954
# min       20.000000                 1.000000
# 25%       39.000000                25.000000
# 50%       58.000000                50.000000
# 75%       78.000000                74.750000
# max      100.000000               100.000000

# %%
# Categorical columns statistics
df.describe(include=['category'])
# Out:
#                    Category        Status
# count                   990           990
# unique                    7             3
# top     Fruits & Vegetables  Discontinued
# freq                    332           333

# %%
# String columns statistics
df.describe(include=['object'])
# Out:
#          Product_ID Product_Name  Supplier_ID Supplier_Name Warehouse_Location
# count           990          990          990           990                990
# unique          990          121          990           350                990
# top     29-205-1132  Bread Flour  38-037-1699          Katz   48 Del Sol Trail
# freq              1           19            1            12                  1

# %%
# Date Range
print(f'Date Min value\n{df[['Date_Received', 'Last_Order_Date', 'Expiration_Date']].min()}')
print(30 * '-')
print(f'Date Max value\n{df[['Date_Received', 'Last_Order_Date', 'Expiration_Date']].max()}')
# Out:
# Date Min value
# Date_Received     2024-02-25
# Last_Order_Date   2024-02-25
# Expiration_Date   2024-02-25
# dtype: datetime64[ns]
# ------------------------------
# Date Max value
# Date_Received     2025-02-24
# Last_Order_Date   2025-02-24
# Expiration_Date   2025-02-24
# dtype: datetime64[ns]

# %%
# create Sales Percent Total Value
perc_sales_volume = (df['Sales_Volume'] / (df['Sales_Volume'].sum())) * 100
df.insert(14, 'Sales_Volume(%)', value=perc_sales_volume)

# %%
# calculate Total Values
df.insert(9, 'Stock_Value', (df['Stock_Quantity'] * df['Unit_Price']))
df.insert(10, 'Reorder_Value', (df['Reorder_Quantity'] * df['Unit_Price']))

# %%
# create Stock Percent Total Value
perc_stock = (df['Stock_Value'] / (df['Stock_Value'].sum())) * 100
df.insert(10, 'Stock_Value(%)', value=perc_stock)

# create Reorder Percent Total Value
perc_reorder = (df['Reorder_Value'] / (df['Reorder_Value'].sum())) * 100
df.insert(12, 'Reorder_Value(%)', value=perc_reorder)

# %%
diff = df['Date_Received'] - df['Last_Order_Date']
df.insert(15, 'LeadTime(days)' , diff.dt.days)

# %%
# Status_Order
df['Purchase_Order'] = np.where(df['LeadTime(days)'] < 0, 'Active', 'Inactive')

# %%
# Expiration Date in days
days_exp = df['Expiration_Date'] - df['Date_Received']
df.insert(17, 'Days_For_Expiration', days_exp.dt.days)

# %%
df.insert(18, 'Expiration_Status', np.where(df['Days_For_Expiration'] < 0, 'Expired', 
         np.where(df['Days_For_Expiration'] < 30, 'Attention(<30d)', 'Good')))

# %%
df['Expiration_Status'] = df['Expiration_Status'].astype('category')
df['Purchase_Order'] = df['Purchase_Order'].astype('category')

# %%
df
# Out:
#       Product_ID     Product_Name             Category  Supplier_ID  \
# 0    29-205-1132       Sushi Rice      Grains & Pulses  38-037-1699
# 1    40-681-9981   Arabica Coffee            Beverages  54-470-2479
# 2    06-955-3428       Black Rice      Grains & Pulses  54-031-2945
# 3    71-594-6552  Long Grain Rice      Grains & Pulses  63-492-7603
# 4    57-437-1828             Plum  Fruits & Vegetables  54-226-4308
# ..           ...              ...                  ...          ...
# 985  82-977-7752          Spinach  Fruits & Vegetables  57-473-8672
# 986  62-393-9939   Cheddar Cheese                Dairy  93-877-9384
# 987  31-745-6850          Cabbage  Fruits & Vegetables  96-215-2767
# 988  86-692-2312      Avocado Oil          Oils & Fats  77-783-4107
# 989  28-044-4102           Papaya  Fruits & Vegetables  93-358-1118
#
#     Supplier_Name  Stock_Quantity  Reorder_Level  Reorder_Quantity  \
# 0       Jaxnation              22             72                70
# 1         Feedmix              45             77                 2
# 2          Vinder              30             38                83
# 3      Brightbean              12             59                62
# 4      Topicstorm              37             30                74
# ..            ...             ...            ...               ...
# 985  Shuffledrive              88             78                17
# 986       Gabcube              60              9                89
# 987          Lajo              94             90                12
# 988  Dazzlesphere              30             48                52
# 989        Yakijo              19             28                83
#
#      Unit_Price  Stock_Value  Stock_Value(%)  Reorder_Value  Reorder_Value(%)  \
# 0           4.5         99.0        0.029761          315.0          0.103115
# 1          20.0        900.0        0.270551           40.0          0.013094
# 2           6.0        180.0        0.054110          498.0          0.163019
# 3           1.5         18.0        0.005411           93.0          0.030443
# 4           4.0        148.0        0.044491          296.0          0.096895
# ..          ...          ...             ...            ...               ...
# 985         2.5        220.0        0.066135           42.5          0.013912
# 986         9.0        540.0        0.162330          801.0          0.262206
# 987         0.9         84.6        0.025432           10.8          0.003535
# 988        10.0        300.0        0.090184          520.0          0.170221
# 989         4.5         85.5        0.025702          373.5          0.122265
#
#     Date_Received Last_Order_Date  LeadTime(days) Expiration_Date  \
# 0      2024-08-16      2024-06-29              48      2024-09-19
# 1      2024-11-01      2024-05-29             156      2024-05-08
# 2      2024-08-03      2024-06-10              54      2024-09-22
# 3      2024-12-08      2025-02-19             -73      2024-04-17
# 4      2024-07-03      2024-10-11            -100      2024-10-05
# ..            ...             ...             ...             ...
# 985    2024-09-06      2024-12-28            -113      2024-11-04
# 986    2024-06-01      2024-06-02              -1      2024-10-05
# 987    2024-10-03      2024-10-24             -21      2024-11-01
# 988    2024-06-11      2024-12-07            -179      2024-04-30
# 989    2024-11-26      2024-03-01             270      2024-08-27
#
#      Days_For_Expiration Expiration_Status        Warehouse_Location  \
# 0                     34              Good          48 Del Sol Trail
# 1                   -177           Expired              36 3rd Place
# 2                     50              Good         3296 Walton Court
# 3                   -235           Expired    3 Westerfield Crossing
# 4                     94              Good      15068 Scoville Court
# ..                   ...               ...                       ...
# 985                   59              Good        58 Corscot Terrace
# 986                  126              Good             5 Oxford Pass
# 987                   29   Attention(<30d)             081 Jana Lane
# 988                  -42           Expired  00616 Manitowish Parkway
# 989                  -91           Expired   309 Burning Wood Center
#
#      Sales_Volume  Sales_Volume(%)  Inventory_Turnover_Rate        Status  \
# 0              32         0.054855                       19  Discontinued
# 1              85         0.145708                        1  Discontinued
# 2              31         0.053140                       34   Backordered
# 3              95         0.162850                       99        Active
# 4              62         0.106281                       25   Backordered
# ..            ...              ...                      ...           ...
# 985            58         0.099424                       21        Active
# 986            95         0.162850                       63        Active
# 987            98         0.167992                       71        Active
# 988            22         0.037713                       78        Active
# 989            91         0.155993                       73  Discontinued
#
#     Purchase_Order
# 0         Inactive
# 1         Inactive
# 2         Inactive
# 3           Active
# 4           Active
# ..             ...
# 985         Active
# 986         Active
# 987         Active
# 988         Active
# 989       Inactive
#
# [990 rows x 25 columns]

# %%
df.info(max_cols=None)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product_ID               990 non-null    object
#  1   Product_Name             990 non-null    object
#  2   Category                 990 non-null    category
#  3   Supplier_ID              990 non-null    object
#  4   Supplier_Name            990 non-null    object
#  5   Stock_Quantity           990 non-null    int64
#  6   Reorder_Level            990 non-null    int64
#  7   Reorder_Quantity         990 non-null    int64
#  8   Unit_Price               990 non-null    float64
#  9   Stock_Value              990 non-null    float64
#  10  Stock_Value(%)           990 non-null    float64
#  11  Reorder_Value            990 non-null    float64
#  12  Reorder_Value(%)         990 non-null    float64
#  13  Date_Received            990 non-null    datetime64[ns]
#  14  Last_Order_Date          990 non-null    datetime64[ns]
#  15  LeadTime(days)           990 non-null    int64
#  16  Expiration_Date          990 non-null    datetime64[ns]
#  17  Days_For_Expiration      990 non-null    int64
#  18  Expiration_Status        990 non-null    category
#  19  Warehouse_Location       990 non-null    object
#  20  Sales_Volume             990 non-null    int64
#  21  Sales_Volume(%)          990 non-null    float64
#  22  Inventory_Turnover_Rate  990 non-null    int64
#  23  Status                   990 non-null    category
#  24  Purchase_Order           990 non-null    category
# dtypes: category(4), datetime64[ns](3), float64(6), int64(7), object(5)
# memory usage: 167.1+ KB

# %%
df.groupby(['Category'])['Product_ID'].count()
# Out:
# Category
# Bakery                  74
# Beverages               75
# Dairy                  180
# Fruits & Vegetables    332
# Grains & Pulses        162
# Oils & Fats             77
# Seafood                 90
# Name: Product_ID, dtype: int64

# %%
df.groupby(['Category', 'Expiration_Status', 'Purchase_Order'])[['Sales_Volume', 'Stock_Value']].sum()
# Out:
#                                                       Sales_Volume  \
# Category            Expiration_Status Purchase_Order
# Bakery              Attention(<30d)   Active                   160
#                                       Inactive                  32
#                     Expired           Active                   590
#                                       Inactive                1463
#                     Good              Active                  1645
#                                       Inactive                 674
# Beverages           Attention(<30d)   Active                   373
#                                       Inactive                  36
#                     Expired           Active                   830
#                                       Inactive                1647
#                     Good              Active                  1476
#                                       Inactive                 171
# Dairy               Attention(<30d)   Active                   504
#                                       Inactive                 240
#                     Expired           Active                  1823
#                                       Inactive                3529
#                     Good              Active                  3144
#                                       Inactive                1532
# Fruits & Vegetables Attention(<30d)   Active                   878
#                                       Inactive                 779
#                     Expired           Active                  3506
#                                       Inactive                5413
#                     Good              Active                  6052
#                                       Inactive                2769
# Grains & Pulses     Attention(<30d)   Active                   237
#                                       Inactive                 327
#                     Expired           Active                  1863
#                                       Inactive                2567
#                     Good              Active                  2869
#                                       Inactive                1023
# Oils & Fats         Attention(<30d)   Active                   224
#                                       Inactive                  71
#                     Expired           Active                   674
#                                       Inactive                1753
#                     Good              Active                  1481
#                                       Inactive                 403
# Seafood             Attention(<30d)   Active                   269
#                                       Inactive                  76
#                     Expired           Active                   901
#                                       Inactive                2374
#                     Good              Active                  1247
#                                       Inactive                 711
#
#                                                       Stock_Value
# Category            Expiration_Status Purchase_Order
# Bakery              Attention(<30d)   Active               275.80
#                                       Inactive             265.50
#                     Expired           Active              1394.95
#                                       Inactive            5991.25
#                     Good              Active              6271.40
#                                       Inactive            2589.90
# Beverages           Attention(<30d)   Active              2500.00
#                                       Inactive             900.00
#                     Expired           Active             11189.50
#                                       Inactive           24438.50
#                     Good              Active             21024.85
#                                       Inactive            2889.40
# Dairy               Attention(<30d)   Active              1521.60
#                                       Inactive            1985.50
#                     Expired           Active              8989.20
#                                       Inactive           15786.95
#                     Good              Active             14247.85
#                                       Inactive            8070.85
# Fruits & Vegetables Attention(<30d)   Active              2692.10
#                                       Inactive            2892.07
#                     Expired           Active             14335.54
#                                       Inactive           27701.69
#                     Good              Active             21212.36
#                                       Inactive           21791.35
# Grains & Pulses     Attention(<30d)   Active               496.25
#                                       Inactive            1394.50
#                     Expired           Active              8529.00
#                                       Inactive            7771.85
#                     Good              Active              9272.85
#                                       Inactive            4504.75
# Oils & Fats         Attention(<30d)   Active              1056.00
#                                       Inactive              72.00
#                     Expired           Active              1790.00
#                                       Inactive            6144.60
#                     Good              Active              5983.90
#                                       Inactive            2165.00
# Seafood             Attention(<30d)   Active              4460.50
#                                       Inactive            1602.00
#                     Expired           Active             11516.50
#                                       Inactive           27263.90
#                     Good              Active             10733.00
#                                       Inactive            6940.00

# %%
df.groupby(['Supplier_Name'])[['LeadTime(days)']].sum().sort_values(by='LeadTime(days)', ascending=False)
# Out:
#                LeadTime(days)
# Supplier_Name
# Gigashots                 938
# Devpulse                  747
# Rhyloo                    710
# Trunyx                    682
# Shufflester               632
# ...                       ...
# Eidel                    -556
# Quatz                    -566
# Mydeo                    -578
# BlogXS                   -847
# Feedfire                 -873
#
# [350 rows x 1 columns]

# %%
df[df['Supplier_Name'] == 'Gigashots']
# Out:
#       Product_ID     Product_Name             Category  Supplier_ID  \
# 258  19-214-5762             Pear  Fruits & Vegetables  88-108-3774
# 332  65-145-9672  Long Grain Rice      Grains & Pulses  65-068-1200
# 539  93-015-0811        Pineapple  Fruits & Vegetables  07-055-5188
# 752  85-835-3445      Egg (Goose)                Dairy  13-433-4930
# 814  10-555-5971  Sourdough Bread               Bakery  30-410-3509
# 829  40-126-0515           Carrot  Fruits & Vegetables  78-379-0369
#
#     Supplier_Name  Stock_Quantity  Reorder_Level  Reorder_Quantity  \
# 258     Gigashots              41             52                75
# 332     Gigashots              71             10                49
# 539     Gigashots              18              7                58
# 752     Gigashots              50             93                37
# 814     Gigashots              94             56                80
# 829     Gigashots              74             37                57
#
#      Unit_Price  Stock_Value  Stock_Value(%)  Reorder_Value  Reorder_Value(%)  \
# 258        4.50        184.5        0.055463         337.50          0.110480
# 332        1.50        106.5        0.032015          73.50          0.024060
# 539        3.50         63.0        0.018939         203.00          0.066452
# 752        2.45        122.5        0.036825          90.65          0.029674
# 814        4.00        376.0        0.113030         320.00          0.104751
# 829        1.50        111.0        0.033368          85.50          0.027988
#
#     Date_Received Last_Order_Date  LeadTime(days) Expiration_Date  \
# 258    2024-04-06      2024-04-24             -18      2024-10-13
# 332    2024-08-11      2024-03-16             148      2024-05-26
# 539    2024-11-26      2024-08-05             113      2024-06-26
# 752    2025-01-11      2024-03-02             315      2024-05-12
# 814    2025-01-04      2024-12-02              33      2024-09-27
# 829    2025-02-14      2024-03-04             347      2024-12-18
#
#      Days_For_Expiration Expiration_Status       Warehouse_Location  \
# 258                  190              Good         7 Bonner Terrace
# 332                  -77           Expired      8 Dovetail Junction
# 539                 -153           Expired          1 Pleasure Hill
# 752                 -244           Expired      288 Fair Oaks Place
# 814                  -99           Expired  8425 New Castle Parkway
# 829                  -58           Expired      28351 Cascade Plaza
#
#      Sales_Volume  Sales_Volume(%)  Inventory_Turnover_Rate        Status  \
# 258            57         0.097710                       62   Backordered
# 332            66         0.113138                       43        Active
# 539            88         0.150850                       96  Discontinued
# 752            78         0.133708                       79   Backordered
# 814            47         0.080568                       96   Backordered
# 829            91         0.155993                       18        Active
#
#     Purchase_Order
# 258         Active
# 332       Inactive
# 539       Inactive
# 752       Inactive
# 814       Inactive
# 829       Inactive

# %%
df[~(df['Status'] == 'Discontinued')]
# Out:
#       Product_ID     Product_Name             Category  Supplier_ID  \
# 2    06-955-3428       Black Rice      Grains & Pulses  54-031-2945
# 3    71-594-6552  Long Grain Rice      Grains & Pulses  63-492-7603
# 4    57-437-1828             Plum  Fruits & Vegetables  54-226-4308
# 6    71-516-1996         Corn Oil          Oils & Fats  04-391-7610
# 8    66-268-8345     Greek Yogurt                Dairy  32-182-1895
# ..           ...              ...                  ...          ...
# 984  53-805-9523  Sourdough Bread               Bakery  99-864-0256
# 985  82-977-7752          Spinach  Fruits & Vegetables  57-473-8672
# 986  62-393-9939   Cheddar Cheese                Dairy  93-877-9384
# 987  31-745-6850          Cabbage  Fruits & Vegetables  96-215-2767
# 988  86-692-2312      Avocado Oil          Oils & Fats  77-783-4107
#
#     Supplier_Name  Stock_Quantity  Reorder_Level  Reorder_Quantity  \
# 2          Vinder              30             38                83
# 3      Brightbean              12             59                62
# 4      Topicstorm              37             30                74
# 6         Tagfeed              96             52                16
# 8    Thoughtstorm              91             84                11
# ..            ...             ...            ...               ...
# 984        Rhyloo              40             30                65
# 985  Shuffledrive              88             78                17
# 986       Gabcube              60              9                89
# 987          Lajo              94             90                12
# 988  Dazzlesphere              30             48                52
#
#      Unit_Price  Stock_Value  Stock_Value(%)  Reorder_Value  Reorder_Value(%)  \
# 2           6.0        180.0        0.054110          498.0          0.163019
# 3           1.5         18.0        0.005411           93.0          0.030443
# 4           4.0        148.0        0.044491          296.0          0.096895
# 6           2.5        240.0        0.072147           40.0          0.013094
# 8           3.0        273.0        0.082067           33.0          0.010802
# ..          ...          ...             ...            ...               ...
# 984         4.5        180.0        0.054110          292.5          0.095749
# 985         2.5        220.0        0.066135           42.5          0.013912
# 986         9.0        540.0        0.162330          801.0          0.262206
# 987         0.9         84.6        0.025432           10.8          0.003535
# 988        10.0        300.0        0.090184          520.0          0.170221
#
#     Date_Received Last_Order_Date  LeadTime(days) Expiration_Date  \
# 2      2024-08-03      2024-06-10              54      2024-09-22
# 3      2024-12-08      2025-02-19             -73      2024-04-17
# 4      2024-07-03      2024-10-11            -100      2024-10-05
# 6      2024-03-18      2024-05-07             -50      2024-06-20
# 8      2024-12-04      2024-06-02             185      2025-01-08
# ..            ...             ...             ...             ...
# 984    2024-07-02      2024-03-19             105      2024-05-14
# 985    2024-09-06      2024-12-28            -113      2024-11-04
# 986    2024-06-01      2024-06-02              -1      2024-10-05
# 987    2024-10-03      2024-10-24             -21      2024-11-01
# 988    2024-06-11      2024-12-07            -179      2024-04-30
#
#      Days_For_Expiration Expiration_Status        Warehouse_Location  \
# 2                     50              Good         3296 Walton Court
# 3                   -235           Expired    3 Westerfield Crossing
# 4                     94              Good      15068 Scoville Court
# 6                     94              Good            12 Truax Court
# 8                     35              Good         550 Clemons Plaza
# ..                   ...               ...                       ...
# 984                  -49           Expired         94 Mallory Center
# 985                   59              Good        58 Corscot Terrace
# 986                  126              Good             5 Oxford Pass
# 987                   29   Attention(<30d)             081 Jana Lane
# 988                  -42           Expired  00616 Manitowish Parkway
#
#      Sales_Volume  Sales_Volume(%)  Inventory_Turnover_Rate       Status  \
# 2              31         0.053140                       34  Backordered
# 3              95         0.162850                       99       Active
# 4              62         0.106281                       25  Backordered
# 6              67         0.114852                       13       Active
# 8              56         0.095996                       90       Active
# ..            ...              ...                      ...          ...
# 984            54         0.092567                       29       Active
# 985            58         0.099424                       21       Active
# 986            95         0.162850                       63       Active
# 987            98         0.167992                       71       Active
# 988            22         0.037713                       78       Active
#
#     Purchase_Order
# 2         Inactive
# 3           Active
# 4           Active
# 6           Active
# 8         Inactive
# ..             ...
# 984       Inactive
# 985         Active
# 986         Active
# 987         Active
# 988         Active
#
# [657 rows x 25 columns]
